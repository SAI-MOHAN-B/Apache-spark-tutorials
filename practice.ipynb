# %%
# !pip install pyspark
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/317.0 MB ? eta -:--:--
#                                               0.0/317.0 MB 1.9 MB/s eta 0:02:46
#                                               0.1/317.0 MB 1.3 MB/s eta 0:04:04
#                                               0.2/317.0 MB 1.7 MB/s eta 0:03:10
#                                               0.3/317.0 MB 1.8 MB/s eta 0:03:00
#                                               0.4/317.0 MB 2.0 MB/s eta 0:02:38
#                                               0.5/317.0 MB 2.2 MB/s eta 0:02:25
#                                               0.6/317.0 MB 2.2 MB/s eta 0:02:22
#                                               0.7/317.0 MB 2.2 MB/s eta 0:02:27
#                                               0.8/317.0 MB 2.4 MB/s eta 0:02:15
# ...

# %%
import pysark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pysark
#
# ModuleNotFoundError: No module named 'pysark'

# %%
import pyspark

# %%
import pandas as pd

# %%
pwd
# Out:
# 'E:\\Jupyter notebook\\Practice'

# %%
pd.read_csv('test.csv')
# Out:
#        name  age  experience
# 0      john   23          10
# 1      mary   24           8
# 2  john doe   25           9

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://SAYONARA.lan:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_spark = spark.read.csv('test.csv')

# %%
df_spark
# Out:
# DataFrame[_c0: string, _c1: string]

# %%
df_spark.show()
# Out:
# +--------+---+
# |     _c0|_c1|
# +--------+---+
# |    name|age|
# |    john| 23|
# |    mary| 24|
# |john doe| 25|
# +--------+---+

# %%
spark.read.option('header','true').csv('industry.csv').show()
# Out:
# +--------------------+
# |            Industry|
# +--------------------+
# |  Accounting/Finance|
# |Advertising/Publi...|
# |  Aerospace/Aviation|
# |Arts/Entertainmen...|
# |          Automotive|
# |    Banking/Mortgage|
# |Business Development|
# |Business Opportunity|
# |Clerical/Administ...|
# |Construction/Faci...|
# |      Consumer Goods|
# |    Customer Service|
# |  Education/Training|
# |    Energy/Utilities|
# |         Engineering|
# | Government/Military|
# |               Green|
# |          Healthcare|
# |  Hospitality/Travel|
# |     Human Resources|
# +--------------------+
# only showing top 20 rows

# %%
df_spark.head(3)
# Out:
# [Row(_c0='name', _c1='age'),
#  Row(_c0='john', _c1='23'),
#  Row(_c0='mary', _c1='24')]

# %%
df_spark.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Dataframe').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://SAYONARA.lan:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
## read the dataset
### here the Experience is given in terms of integer
### But the schema is reading as string by default so
## To have the individiual data types we need inferSchema
df_spark = spark.read.option('header','true').csv('test.csv',inferSchema=True)

# %%
### check the schema
df_spark.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- experience: integer (nullable = true)

# %%
df_spark = spark.read.csv('test.csv',header = True,inferSchema = True)
df_spark.show()
# Out:
# +--------+---+----------+
# |    name|age|experience|
# +--------+---+----------+
# |    john| 23|        10|
# |    mary| 24|         8|
# |john doe| 25|         9|
# +--------+---+----------+

# %%
df_spark.columns
# Out:
# ['name', 'age', 'experience']

# %%
df_spark.show()
# Out:
# +--------+---+----------+
# |    name|age|experience|
# +--------+---+----------+
# |    john| 23|        10|
# |    mary| 24|         8|
# |john doe| 25|         9|
# +--------+---+----------+

# %%
df_spark.select('name').show()
# Out:
# +--------+
# |    name|
# +--------+
# |    john|
# |    mary|
# |john doe|
# +--------+

# %%
### to select the multiple columns
df_spark.select(['name','experience']).show()
# Out:
# +--------+----------+
# |    name|experience|
# +--------+----------+
# |    john|        10|
# |    mary|         8|
# |john doe|         9|
# +--------+----------+

# %%
test_data = df_spark.select(['name','experience'])
print(type(test_data))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
df_spark['name']
# Out:
# Column<'name'>

# %%
### to check the data types

# %%
df_spark.dtypes
# Out:
# [('name', 'string'), ('age', 'int'), ('experience', 'int')]

# %%
df_spark.describe().show()
# Out:
# +-------+----+----+----------+
# |summary|name| age|experience|
# +-------+----+----+----------+
# |  count|   3|   3|         3|
# |   mean|NULL|24.0|       9.0|
# | stddev|NULL| 1.0|       1.0|
# |    min|john|  23|         8|
# |    max|mary|  25|        10|
# +-------+----+----+----------+

# %%
### Adding Columns in data frame
df_spark.withColumn('Experience After 2 year',df_spark['experience']+2)
# Out:
# DataFrame[name: string, age: int, experience: int, Experience After 2 year: int]

# %%
### using show
df_spark = df_spark.withColumn('Experience After 2 year',df_spark['experience']+2)

# %%
df_spark
# Out:
# DataFrame[name: string, age: int, experience: int, Experience After 2 year: int]

# %%
df_spark.show()
# Out:
# +--------+---+----------+-----------------------+
# |    name|age|experience|Experience After 2 year|
# +--------+---+----------+-----------------------+
# |    john| 23|        10|                     12|
# |    mary| 24|         8|                     10|
# |john doe| 25|         9|                     11|
# +--------+---+----------+-----------------------+

# %%
### Drop Columns
df_spark = df_spark.drop('Experience After 2 year')

# %%
df_spark.show()
# Out:
# +--------+---+----------+
# |    name|age|experience|
# +--------+---+----------+
# |    john| 23|        10|
# |    mary| 24|         8|
# |john doe| 25|         9|
# +--------+---+----------+

# %%
#### Rename the Columms
df_spark.withColumnRenamed('name','new name').show()
# Out:
# +--------+---+----------+
# |new name|age|experience|
# +--------+---+----------+
# |    john| 23|        10|
# |    mary| 24|         8|
# |john doe| 25|         9|
# +--------+---+----------+
